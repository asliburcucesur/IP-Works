# %%
import pandas as pd
df = pd.read_csv("country_vaccination_stats.csv")
df.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
df.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
df["daily_vaccinations"] = df.groupby("country")["daily_vaccinations"].transform(lambda x: x.fillna(x.min()))
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020              6483.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    1
# vaccines              0
# dtype: int64

# %%
df["daily_vaccinations"]=df["daily_vaccinations"].fillna(0)

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64

# %%
df.loc[df["country"]=="Kuwait"]
# Out:
#     country        date  daily_vaccinations         vaccines
# 750  Kuwait  12/28/2020                 0.0  Pfizer/BioNTech

# %%
median_df= df.groupby("country")[["daily_vaccinations"]].agg(lambda x: x.astype(int).median())

# %%
median_df
# Out:
#                       daily_vaccinations
# country
# Argentina                        11645.0
# Austria                           7850.0
# Bahrain                           3662.0
# Belgium                           3606.0
# Brazil                           17220.0
# Bulgaria                          1010.0
# Canada                           11044.0
# Chile                             1291.0
# China                           276786.0
# Costa Rica                         675.5
# Croatia                           2485.0
# Cyprus                             708.0
# Czechia                           5378.0
# Denmark                           7095.5
# Ecuador                            108.0
# England                         107310.5
# Estonia                           1043.0
# Finland                           2035.5
# France                           41496.0
# Germany                          51184.0
# Gibraltar                          713.0
# Greece                            5290.0
# ...

# %%
df.loc[df["country"]=="Ecuador"]
# Out:
#      country       date  daily_vaccinations         vaccines
# 384  Ecuador  1/21/2021               108.0  Pfizer/BioNTech
# 385  Ecuador  1/22/2021               108.0  Pfizer/BioNTech

# %%
median_df.sort_values(by=["daily_vaccinations"]).tail(3)
# Out:
#                daily_vaccinations
# country
# India                    173922.0
# China                    276786.0
# United States            378253.0

# %%
date_df =df[df["date"]=="1/6/2021"]
date_df
# Out:
#                    country      date  daily_vaccinations  \
# 8                Argentina  1/6/2021              8173.0
# 29                 Austria  1/6/2021              3368.0
# 62                 Bahrain  1/6/2021              1594.0
# 86                 Belgium  1/6/2021               736.0
# 121               Bulgaria  1/6/2021               472.0
# 164                 Canada  1/6/2021             14887.0
# 197                  Chile  1/6/2021               272.0
# 239                  China  1/6/2021            455357.0
# 267             Costa Rica  1/6/2021               763.0
# 287                Croatia  1/6/2021              1334.0
# 307                 Cyprus  1/6/2021               534.0
# 334                Czechia  1/6/2021              2439.0
# 364                Denmark  1/6/2021              8525.0
# 403                England  1/6/2021             98984.0
# 431                Estonia  1/6/2021               589.0
# ...

# %%
len(date_df)
# Out:
# 48
